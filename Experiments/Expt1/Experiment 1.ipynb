# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv("../datasets/breast-cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
df.columns.values
# Out:
# array(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean',
#        'concavity_mean', 'concave points_mean', 'symmetry_mean',
#        'fractal_dimension_mean', 'radius_se', 'texture_se',
#        'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se',
#        'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype=object)

# %% [markdown]
# ## Data Preprocessing

# %%
df.drop(columns = ["id", "Unnamed: 32"], inplace = True)

# %%
df.head(10)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
# 5         M        12.45         15.70           82.57      477.1
# 6         M        18.25         19.98          119.60     1040.0
# 7         M        13.71         20.83           90.20      577.9
# 8         M        13.00         21.82           87.50      519.8
# 9         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# ...

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.corr()
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
benign, malignant=df['diagnosis'].value_counts()
print("No of Benign cells: ", benign)
print("No of malignant cells: ", malignant)
# Out:
# No of Benign cells:  357
# No of malignant cells:  212

# %%
print("% of Benign cell is: ", benign*100/len(df))
print("% of Malignant cell is: ", malignant*100/len(df))
# Out:
# % of Benign cell is:  62.74165202108963
# % of Malignant cell is:  37.25834797891037

# %%
sns.countplot(df['diagnosis'], label="Count")

# %%
df.diagnosis.value_counts().plot(kind = 'pie',shadow = True,colors = ('purple','yellow'), autopct = '%.2f', figsize = (5,5))
plt.title('Diagnosis')
plt.show()

# %%
corr = df.corr().round(2) # .corr is used for find corelation
mask=np.zeros_like(corr, dtype=np.bool)
f, ax = plt.subplots(figsize=(20, 20)) # Set figure size
hmap = sns.heatmap(corr, mask=mask, cmap="viridis", vmin=-1, vmax=1, center=0, square=True, linewidths=.5, 
                   cbar_kws={"shrink": .5}, annot=True)
bottom, top = hmap.get_ylim()
hmap.set_ylim(bottom + 0.5, top - 0.5)
plt.tight_layout()

# %%
f, ax = plt.subplots(figsize=(20, 20))
mask[np.triu_indices_from(mask)] = True
compact_hmap = sns.heatmap(corr, mask=mask, cmap="viridis", vmin=-1, vmax=1, center=0, square=True, linewidths=.5, 
            cbar_kws={"shrink": .5}, annot=True)
bottom, top = compact_hmap.get_ylim()
compact_hmap.set_ylim(bottom + 0.5, top - 0.5)
plt.tight_layout()

# %%
features_mean = list(df.columns[:11])
plt.figure(figsize = (10,10))
sns.pairplot(data = df[features_mean], hue = 'diagnosis', palette = 'RdBu')

# %%
M = df[df.diagnosis == 'M']
M.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
B = df[df.diagnosis == 'B']
B.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19         B       13.540         14.36           87.46      566.3
# 20         B       13.080         15.71           85.63      520.0
# 21         B        9.504         12.44           60.34      273.9
# 37         B       13.030         18.42           82.61      523.8
# 46         B        8.196         16.84           51.71      201.9
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 19          0.09779           0.08129         0.06664             0.047810
# 20          0.10750           0.12700         0.04568             0.031100
# 21          0.10240           0.06492         0.02956             0.020760
# 37          0.08983           0.03766         0.02562             0.029230
# 46          0.08600           0.05943         0.01588             0.005917
#
#     symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
plt.title("Malignant vs Benign Tumor")
plt.xlabel("Radius Mean")
plt.ylabel("Texture Mean")
plt.scatter(M.radius_mean, M.texture_mean, color = "green", label = "Malignant", alpha = 0.5)
plt.scatter(B.radius_mean, B.texture_mean, color = "blue", label = "Benign", alpha = 0.5)
plt.show()

# %% [markdown]
# ## Splitting Dataset

# %%
df['diagnosis'] = df['diagnosis'].map({'M' : 1,'B' : 0})
X = df.drop(["diagnosis"], axis = 1)
y = df.diagnosis.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## Feature Scaling: Min-Max Normalization
# The min-max normalizer linearly rescales every feature to the [0,1] interval.
# Rescaling to the [0,1] interval is done by shifting the values of each feature so that the minimal value is 0, and then dividing by the new maximal value (which is the difference between the original maximal and minimal values).
# The values in the column are transformed using the following formula:
#
#
# X = (X - min(X))/(max(X) - X)

# %%
from sklearn.preprocessing import MinMaxScaler
mmc = MinMaxScaler()
X_train = mmc.fit_transform(X_train)
X_test = mmc.transform(X_test)

# %% [markdown]
# ## Creating Decision Tree Classifier and Analyzing performance

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
y_pred = classifier.predict(X_test)

# %%
classifier.score(X_test, y_test)
# Out:
# 0.958041958041958

# %% [markdown]
# ### Confusion Matrix and Classification Report

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
ax = sns.heatmap(cm, annot=True, fmt='d', cmap="YlOrBr")
ax.set_ylim([0,2])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        90
#            1       0.93      0.96      0.94        53
#
#     accuracy                           0.96       143
#    macro avg       0.95      0.96      0.96       143
# weighted avg       0.96      0.96      0.96       143

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(30,30))
dec_tree = plot_tree(decision_tree = classifier, 
                     feature_names = df.columns, 
                     class_names = ["Malignant", "Benign"], 
                     filled = True, 
                     precision = 4, 
                     rounded = True)
plt.savefig("D:\\Dropbox\\Shubhra\\Shubhra Docs\\Practical Files\\ML\\Expt1\\decisionTree.png")
