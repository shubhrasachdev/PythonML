# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Warnings
import warnings
warnings.filterwarnings('ignore')

from sklearn.cluster import KMeans

# %%
df1 = pd.read_csv("Country-data.csv")
df2 = pd.read_csv("creditcard.csv")

# %%
df1.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
df2.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
np.unique(df2["Class"].values)
# Out:
# array([0, 1], dtype=int64)

# %%
df11 = df2[df2.columns[1:]]
df21 = df2[df2.columns[:-1]]

# %%
X1 = df11.values
X2 = df21.values

# %%
X1.shape, X2.shape
# Out:
# ((284807, 30), (284807, 30))

# %% [markdown]
# ### Country Data for k = 2

# %%
model = KMeans(n_clusters=2, init = 'k-means++', max_iter=3)
model.fit(X1)
model.inertia_
# Out:
# 8796134682.328894

# %%
model.cluster_centers_
# Out:
# array([[ 4.28165129e-02,  8.14860972e-02,  3.30160133e-02,
#         -1.43767718e-02,  4.69907725e-02, -2.49855220e-02,
#         -4.76823982e-02,  1.27124472e-02,  4.47459346e-03,
#          1.07781261e-02, -4.95761169e-04,  1.14958525e-03,
#         -6.37153365e-05, -4.09874671e-03,  6.47639584e-04,
#         -6.19972499e-04, -1.06255860e-03, -1.32881803e-03,
#          4.04207133e-03, -2.94056088e-02, -8.28161935e-03,
#          6.14948732e-03,  7.10192837e-03, -5.38054982e-04,
#          2.57099087e-03, -3.35433527e-04, -2.97920179e-04,
#         -1.05304306e-03,  6.43376277e+01,  1.70170170e-03],
#        [-2.35436111e+00, -4.48069414e+00, -1.81545886e+00,
#          7.90538748e-01, -2.58389206e+00,  1.37388445e+00,
#          2.62192263e+00, -6.99022161e-01, -2.46045465e-01,
#         -5.92659218e-01,  2.72605296e-02, -6.32124998e-02,
#          3.50352937e-03,  2.25378697e-01, -3.56119018e-02,
#          3.40905656e-02,  5.84271460e-02,  7.30680123e-02,
# ...

# %% [markdown]
# ### Credit Card Data for k = 2

# %%
model = KMeans(n_clusters=2, init = 'k-means++', max_iter=3)
model.fit(X2)
model.inertia_
# Out:
# 118320098723212.64

# %%
model.cluster_centers_
# Out:
# array([[ 5.50434584e+04, -2.35427434e-01,  4.42374324e-02,
#          6.07693489e-01,  1.33231678e-01, -2.40291489e-01,
#          6.95954068e-02, -1.04087210e-01,  5.26975860e-02,
#         -3.49988506e-02, -2.96359740e-02,  2.09500692e-01,
#         -3.19375200e-02,  2.87614030e-02,  5.60144496e-02,
#          1.82419788e-01, -1.18484889e-02,  4.37707633e-02,
#         -7.09958530e-02, -2.11694754e-02,  3.95479180e-02,
#         -3.72058290e-02, -1.09755965e-01, -2.85952040e-02,
#          1.16942416e-02,  1.16687734e-01,  2.29656101e-02,
#          1.86446244e-03,  2.84904737e-03,  8.86570536e+01],
#        [ 1.41072857e+05,  2.73837745e-01, -5.14548305e-02,
#         -7.06839520e-01, -1.54968610e-01,  2.79495377e-01,
#         -8.09499933e-02,  1.21069182e-01, -6.12952698e-02,
#          4.07089613e-02,  3.44711240e-02, -2.43681019e-01,
#          3.71481704e-02, -3.34538655e-02, -6.51532842e-02,
#         -2.12181828e-01,  1.37815862e-02, -5.09120237e-02,
# ...

# %% [markdown]
# ### Country Data for k = 5

# %%
model = KMeans(n_clusters=5, init = 'k-means++', max_iter=3)
model.fit(X1)
model.inertia_
# Out:
# 2556090994.022699

# %%
model.cluster_centers_
# Out:
# array([[ 8.61459592e-02,  1.92877738e-01,  5.79493916e-02,
#         -2.03928494e-02,  1.00009983e-01, -5.05463219e-02,
#         -8.10799591e-02,  2.31381684e-02,  7.94511458e-03,
#          2.16461644e-02,  2.49610418e-03, -1.18008370e-03,
#          3.25407054e-03, -5.96549847e-03,  5.57790399e-03,
#          1.03801339e-02, -3.00303182e-03, -6.01487827e-03,
#          7.93434559e-03, -5.35533693e-02, -1.68156833e-02,
#          4.76311410e-03,  6.63717087e-03,  1.00164680e-03,
#          2.72867380e-03, -1.59253322e-03,  1.35756973e-03,
#         -1.75866190e-03,  4.08771584e+01,  1.59396358e-03],
#        [-2.11331302e+00, -4.07803969e+00, -1.70378526e+00,
#          7.09939849e-01, -2.27362256e+00,  1.19632236e+00,
#          2.32288535e+00, -6.67219819e-01, -2.32340265e-01,
#         -5.17474800e-01,  1.60576849e-02, -4.19333383e-02,
#         -1.56607062e-02,  2.38073372e-01, -3.90708172e-02,
#          3.60324124e-03,  5.23867257e-02,  4.95020206e-02,
# ...

# %% [markdown]
# ### Credit Data for k = 5

# %%
model = KMeans(n_clusters=5, init = 'k-means++', max_iter=3)
model.fit(X2)
model.inertia_
# Out:
# 23862479025049.203

# %%
model.cluster_centers_
# Out:
# array([[ 4.64695259e+04, -2.71423639e-01, -1.17973588e-01,
#          6.57257596e-01,  1.30363160e-01, -3.10996006e-01,
#          9.36558362e-02, -9.94587348e-02,  6.50413537e-02,
#         -2.19732043e-01,  2.59881846e-02,  1.45701845e-01,
#          1.81731591e-01, -1.65781591e-01, -6.64871326e-02,
#          2.45947760e-01, -7.72513359e-03,  2.92598459e-03,
#         -1.09935978e-01, -1.17685457e-02,  4.32927551e-02,
#         -2.43167591e-02, -9.55211498e-02, -3.69437873e-02,
#          8.99417004e-03,  1.35476949e-01,  2.48099094e-02,
#         -2.75504246e-03,  9.25242511e-04,  1.06484972e+02],
#        [ 1.28210558e+05,  2.78663401e-01, -1.41094285e-01,
#         -6.94784762e-01, -1.54108895e-01,  3.00454528e-01,
#         -5.30915637e-02,  1.41337708e-01, -9.15278451e-02,
#          4.67222187e-02,  6.53489736e-02, -2.17114407e-01,
#         -2.14996995e-02, -4.08740277e-02, -4.12185303e-02,
#         -2.08479555e-01,  5.34098808e-03, -5.27776593e-02,
# ...

# %% [markdown]
# ## Using the elbow method to find the optimal number of clusters
#
# ### For Country Data

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter=3, random_state = 42)
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### For credit data

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter=3, random_state = 42)
    kmeans.fit(X2)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
